# %% [markdown]
# **import the required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the Data**

# %% [markdown]
# -here we are reading visa dataset which is CSV type(comma Separated Value)
#
# - It is located in datafiles folder
#
# - In order to read any dataset we need first directory , filename, and Type

# %%
path= r"C:\Users\Rahul\Documents\NareshIT\Data files\Visadataset.csv"

# %%
visa_df = pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path= r"C:\Users\Rahul\Documents\NareshIT\Data files\bank.csv"

# %%
bank_df = pd.read_csv(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 bank_df = pd.read_csv(path)
#
# NameError: name 'pd' is not defined

# %%
bank_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bank_df
#
# NameError: name 'bank_df' is not defined

# %%
how to scrap the data from wikipedia
how to get the reviews from amazon

# %% [markdown]
# **DATA Quick Checks**
# - head
#
# - tail
#
# - shape
#
# - size
#
# - columns
#
# - dtypes
#
# - lock
#
# - iloc
#
# - take

# %%
str1='hello'
dir(str1)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %% [markdown]
# $head$

# %%
# <package_name>.<method_name>

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df.tail(10)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25476  EZYV25477           Asia           High School                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# ...

# %% [markdown]
# $shape$

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
print(f"The number of rows are : {visa_df.shape[0]}")
print(f"The number of rows are : {visa_df.shape[1]}")
# Out:
# The number of rows are : 25480
# The number of rows are : 12

# %% [markdown]
# $Size$

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.shape[0]*visa_df.shape[1]
# Out:
# 305760

# %% [markdown]
# $Columns$

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
len(visa_df)
# Out:
# 25480

# %% [markdown]
# $dtypes$
#
# - dtypes will provide each column datatype
#
# - Object means string data type(Categorical)
#
# - int64, int 32, int 128, float 64 (Numerical)
#
# - dtypes always give in series

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
visa_df.take([2,5])
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 5  EZYV06      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 5                     N             2339         2012                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 5         78252.14         Year                  Y   Certified

# %%
visa_df.loc()

# %%
visa_df.iloc()

# %% [markdown]
# **Task-1**
#
# - I want to create two list
#
# - One is categorical and second one is Numerical column list
#
# - Using dtypes

# %% [markdown]
# - whenever you want to create any list from series first convert the series into a dictionary

# %%
data_types = visa_df.dtypes

dict(data_types)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %% [markdown]
# - When you convert it becomes a key-value pair
#
# - Iterate through dictionary
#
# - if value==object type then keep the ocrrecsponding key in one list
#
# - else keep that variable in other list

# %%
cat_list=[]
num_list=[]
for i,j in dict(data_types).items():
    if j =='object':
        cat_list.append(i)
    else:
        num_list.append(i)

# %%
cat_list=[i for i,j in dict(data_types).items() if j=='object']
num_list=[i for i,j in dict(data_types).items() if j!='object']
cat_list, num_list
# Out:
# (['case_id',
#   'continent',
#   'education_of_employee',
#   'has_job_experience',
#   'requires_job_training',
#   'region_of_employment',
#   'unit_of_wage',
#   'full_time_position',
#   'case_status'],
#  ['no_of_employees', 'yr_of_estab', 'prevailing_wage'])

# %%
for i,j in dict(data_types).items():
    print(i,j)
# Out:
# case_id object
# continent object
# education_of_employee object
# has_job_experience object
# requires_job_training object
# no_of_employees int64
# yr_of_estab int64
# region_of_employment object
# prevailing_wage float64
# unit_of_wage object
# full_time_position object
# case_status object

# %% [markdown]
# - Take dtypes
#
# - Convert into dictionary
#
# - Create two lists cat list and num list
#
# - Create two dataframes

# %%
len(cat_list),len(num_list)
# Out:
# (9, 3)

# %% [markdown]
# - we cannot create a dataframe using these two lists because these two lists are in equal length
#
# - if you want to create a dataframe then we need to make two lists in equal length
#
# - Then you need to question yourselves , making equal length is required or not
#
# - if its required then how

# %%
# creating columns dataframes

num_df = pd.DataFrame(num_list, columns=['Numerical_column'] )
num_df.to_csv('Numerical_column_df.csv',index=False )

# %%
cat_df = pd.DataFrame(cat_list, columns=['Categorical_column'] )
cat_df.to_csv('Categorical_column_df.csv',index=False )

# %% [markdown]
# **Task-2**

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
dict(visa_df.dtypes).keys()
# Out:
# dict_keys(['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'no_of_employees', 'yr_of_estab', 'region_of_employment', 'prevailing_wage', 'unit_of_wage', 'full_time_position', 'case_status'])

# %%
dict(visa_df.dtypes).values()
# Out:
# dict_values([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'), dtype('O'), dtype('O'), dtype('O')])

# %%
cols,data_types = [],[]
for keys,values in dict(visa_df.dtypes).items():
    cols.append(keys)
    data_types.append(values)
    
pd.DataFrame(zip(cols,data_types), columns = ['Columns','Data type'])
# Out:
#                   Columns Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **Task-3**
#
# - We can create a dataFrame using dictionary also

# %%
# create two dictionaries

dict1 = {'Names':['Ashish','Mohith','Manish'],
        'Age':[30,40,60]}

dict1
# Out:
# {'Names': ['Ashish', 'Mohith', 'Manish'], 'Age': [30, 40, 60]}

# %%
pd.DataFrame(dict1)
# Out:
#     Names  Age
# 0  ashish   30
# 1  mohith   40
# 2  manish   60

# %% [markdown]
# - The advantage here is no need to provide column names again, automatically keys behave as column names
#
#
# **Task-4**
# - two lists available cols and datatypes
#
# - create a dict with these two and create a datafarme

# %%
# - two lists available create dict and create a datafarme
d={}
d['Columns']=cols
d['Data types']=data_types

pd.DataFrame(d)


pd.DataFrame(zip(cols,data_types), columns=['Columns','Data type'])
# Out:
#                   Columns Data types
# 0                 case_id     object
# 1               continent     object
# 2   education_of_employee     object
# 3      has_job_experience     object
# 4   requires_job_training     object
# 5         no_of_employees      int64
# 6             yr_of_estab      int64
# 7    region_of_employment     object
# 8         prevailing_wage    float64
# 9            unit_of_wage     object
# 10     full_time_position     object
# 11            case_status     object

# %%
visa_df.select_dtypes(include = 'object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude = 'object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **Task is**
#
# - list to dataframe
#
# - dictionary to dataframe
#
# - list to dictionary
#
# - dict to dataframe
#
# - dict to list and dataframe

# %% [markdown]
# **isnull**
#
# - Null means the element is missed
#
# - Missing Values
#
# - isnull we are asking to computer if any element missed or not
#
# - Then computer will give True or False
#
# - True means the value missed
#
# - false means the value not missed

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.isnull().sum()  # No missing values
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
# whenever you open the notebook
# import the package cell 
# data cell you need to run
# These two lines are in the starting
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# R language is outdated 
# open any google or azure ai python documentation
# everything with python only
complex()
# Out:
# 0j

# %%
path= r"C:\Users\Rahul\Documents\NareshIT\Data files\Visadataset.csv"
visa_df = pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# - head
#
# - tail
#
# - shape
#
# - size
#
# - columns
#
# - dtypes
#
# - isnull
#
# - isnull().sum()
#
# - isna
#
# - info

# %% [markdown]
# **isna**

# %%
# isna and isnull both are same

visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %% [markdown]
# $take$
#
# - first argumet :indices
#
# - indices will take some values in array : in a list
#
# - it tries to extract the data
#
# - that values we provided represents columns or rows?
#
# - Axis 0 represent about rows
#
# - Axis 1 represnts about columns
#
# - By default axis mentioned as zero

# %%
visa_df.take([100,200,300])

# It retrieves 3 rows which has index 100,200,300
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300],axis=1)
# now this will check for 100th, 200th and 300th columns
# But originally we have 12 columns (0,11)
# so we will get error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 visa_df.take([100,200,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
# Case -3: selct columns 2nd, 5th and 7th columns using take
    
visa_df.take([2,5,7],axis=1)
# the output also behave as dataframe
# Out:
#   education_of_employee  no_of_employees region_of_employment
# 3            Bachelor's               98                 West
# 4              Master's             1082                South

# %%
# case-4: Slicing

visa_df.take([2:5])
# Out:
#   Cell In[18], line 3
#     visa_df.take([2:5])
#                    ^
# SyntaxError: invalid syntax

# %%
# Qn is: we want 100,200,300 rows from 2,5,7 columns

# %% [markdown]
# **loc-iloc**

# %%
visa_df.iloc[<rows>,<columns>]
visa_df.iloc[start:stop, start:stop]
visa_df.iloc[start:stop:step, start:stop:step]
visa_df.iloc[[list of rows], [list of columns]]
# case -1: rows = [100,200,300] columns =[2,5,7]
# case -2: rows = [100:105] columns =[2,5,7]
# case -3: rows = [100:105] columns =[2:7]
# case -4: rows = [100,200,300] columns =[2:7]
# case -5: rows = [100,200,300] columns = :
# case -1: rows = : columns =[2,5,7]

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[100:105,[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:105:2,2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 104              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 102              224         2008
# 104              306         2003

# %%
visa_df.iloc[[100,200,300],2:7]
# Out:
#     education_of_employee has_job_experience requires_job_training  \
# 100              Master's                  Y                     N
# 200             Doctorate                  Y                     N
# 300              Master's                  Y                     N
#
#      no_of_employees  yr_of_estab
# 100             2227         2007
# 200             3282         1979
# 300             3268         2012

# %%
visa_df.iloc[[100,200,300]] # same like take only
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[:] # All the data
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.iloc[:,2] # series type
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.iloc[:,[2]] # Dataframe  type

# %%
visa_df.iloc[[2,5,7]] # rows
visa_df.iloc[:,[2,5,7] # columns
visa_df.iloc[:,2] # second column having series type
visa_df.iloc[:,[2]] # second index column having datframe type

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.iloc[:,[2,5,7]]
visa_df.loc[:,['continent','has_job_experience']]
# Out:
#       continent has_job_experience
# 0          Asia                  N
# 1          Asia                  Y
# 2          Asia                  N
# 3          Asia                  N
# 4        Africa                  Y
# ...         ...                ...
# 25475      Asia                  Y
# 25476      Asia                  Y
# 25477      Asia                  Y
# 25478      Asia                  Y
# 25479      Asia                  Y
#
# [25480 rows x 2 columns]

# %%
# Case -1: rows = [100,200,300] columns = name of the columns
# Case -2: rows = [100:105]  columns = name of the columns
# Case -3: rows = [100:105]  columns = name of the columns
# Case -4: rows = [100,200,300]  columns = name of the columns
# Case -5: rows = [100,200,300] columns = name of the columns
# Case -1: rows = :  columns = name of the columns
